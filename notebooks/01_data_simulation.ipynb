# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../data/simulated_data.csv')
df.head()
# Out:
#    time  temperature        ph  nutrients     biomass     product
# 0     0    37.248357  7.071557  96.811145  126.472557  110.560884
# 1     1    36.930868  7.112157  98.501250  118.165063   89.371603
# 2     2    37.323844  7.216610  99.410487  128.051131  103.402113
# 3     3    37.761515  7.210760  99.193961  131.265919  100.389982
# 4     4    36.882923  6.724466  97.899869  123.956354   94.820121

# %%
plt.plot(df['time'], df['biomass'])
plt.title('Biomass over time')
plt.show()
