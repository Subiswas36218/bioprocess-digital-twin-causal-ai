# %%
import pandas as pd
from dowhy import CausalModel

# %%
df = pd.read_csv('../data/simulated_data.csv')
print(df.corr())
# Out:
#                  time  temperature        ph  nutrients   biomass   product
# time         1.000000     0.071231 -0.008088  -0.993523 -0.847315 -0.568839
# temperature  0.071231     1.000000  0.095147  -0.085946  0.051763  0.009192
# ph          -0.008088     0.095147  1.000000   0.004320 -0.044502 -0.127487
# nutrients   -0.993523    -0.085946  0.004320   1.000000  0.857323  0.576545
# biomass     -0.847315     0.051763 -0.044502   0.857323  1.000000  0.714581
# product     -0.568839     0.009192 -0.127487   0.576545  0.714581  1.000000
